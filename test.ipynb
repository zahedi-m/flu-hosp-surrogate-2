# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_map= pd.read_csv("meta_data/mapping_basin_to_state.csv")

# %%
compartments=["Latent", "Hospitalized"]

# %%
y=np.load("data/y_prev_train/61001000000018972y_prev.npy")

# %%
plt.plot(y[:, :, 4].T)

# %%
y= np.load("data/y_inc_train/61001000000270030_y_inc.npy")

# %%
plt.plot(y[:, :, 4].T)

# %%
import torch

# %%
mu= torch.zeros(32, 245, 51)
var= torch.ones(32, 245, 51)
y= torch.randn(32, 245, 51)

# %%
lk=torch.distributions.Normal(mu, var.sqrt()).log_prob(y)

# %%
lk.mean(), lk.mean(dim=[1, 2]).mean()
# Out:
# (tensor(-1.4195), tensor(-1.4195))
